# %% [markdown]
# # 智能股票分析助手 — 主 Notebook
#
# 本仓库以 **FastAPI 后端**（`backend/`）与 **Vue 前端**（`frontend/`）为主；此笔记本用于快速实验、调用本地 API 或调试 `agents` 包。
#
# 启动服务：见根目录 [README.md](../README.md)（`uvicorn` / `npm run dev`）。

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import agents  # 根目录 agents 包
print("agents:", agents.__file__)
